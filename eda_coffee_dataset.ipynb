# %%
import pandas as pd

df = pd.read_csv(r'../Coffee.csv')
df.sample(5)
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 212         212  2018    India               49074.0  27254.0           2.8
# 172         172  2017   Mexico               33669.0  37282.0           3.7
# 188         188  2017  Vietnam               16490.0  29760.0           2.6
# 469         469  2023   Brazil               24662.0  44728.0           2.3
# 134         134  2017   Brazil               22039.0  38843.0           2.1
#
#      Export Price  Total Production
# 212           3.2           74344.0
# 172           3.8           68315.0
# 188           2.7           44975.0
# 469           2.8           66859.0
# 134           2.1           57925.0

# %% [markdown]
# ****1) How many rows and columns are present in the dataset?****

# %%
df.shape
# Out:
# (520, 8)

# %% [markdown]
# ****2) What are the names of all columns in the dataset?****

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Country', 'Domestic Consumption', 'Exports',
#        'Import Price', 'Export Price', 'Total Production'],
#       dtype='str')

# %% [markdown]
# ****3) What is the data type of each column?****

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# Year                      int64
# Country                     str
# Domestic Consumption    float64
# Exports                 float64
# Import Price            float64
# Export Price            float64
# Total Production        float64
# dtype: object

# %% [markdown]
# ****4) Display the first 5 rows of the dataset.****

# %%
df.head(5)
# Out:
#    Unnamed: 0  Year    Country  Domestic Consumption  Exports  Import Price  \
# 0           0  2015  Argentina               13051.0  14887.0           2.6
# 1           1  2015  Argentina               13131.0  15055.0           2.6
# 2           2  2015  Argentina               13305.0  15075.0           2.7
# 3           3  2015     Brazil               21070.0  36806.0           1.9
# 4           4  2015     Canada               18063.0  21734.0           3.9
#
#    Export Price  Total Production
# 0           2.7           26614.0
# 1           3.0           27019.0
# 2           NaN           27232.0
# 3           1.9           54721.0
# 4           4.0           38987.0

# %% [markdown]
# ****5) Display the last 5 rows of the dataset.****

# %%
df.tail(5)
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 515         515  2023      USA               28629.0      0.0           5.3
# 516         516  2023      USA               28875.0      0.0           5.2
# 517         517  2023  Vietnam                   NaN  34342.0           2.9
# 518         518  2023  Vietnam               18557.0  34695.0           3.2
# 519         519  2023  Vietnam               18615.0  34840.0           3.0
#
#      Export Price  Total Production
# 515           0.0               0.0
# 516           0.0               0.0
# 517           3.2           52222.0
# 518           2.9           52867.0
# 519           NaN           52639.0

# %% [markdown]
# ****6) Which columns contain missing values?****

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Year                     0
# Country                  0
# Domestic Consumption    26
# Exports                 26
# Import Price            26
# Export Price            26
# Total Production        26
# dtype: int64

# %% [markdown]
# ****7) How many unique countries are present in the dataset?****

# %%
print(df.Country.unique())
df.Country.nunique()
# Out:
# <StringArray>
# [   'Argentina',       'Brazil',       'Canada',        'Chile',
#         'China',     'Colombia',     'Ethiopia',       'France',
#       'Germany',        'India',    'Indonesia',        'Italy',
#         'Kenya',       'Mexico',         'Peru', 'South Africa',
#      'Thailand',       'Turkey',          'USA',      'Vietnam']
# Length: 20, dtype: str
# 20

# %% [markdown]
# ****8) How many records are available for each year?****

# %%
df['Year'].value_counts()
# Out:
# Year
# 2015    73
# 2021    61
# 2017    59
# 2016    58
# 2020    58
# 2019    57
# 2022    56
# 2023    54
# 2018    44
# Name: count, dtype: int64

# %% [markdown]
# ****9) How many records are available for each country?****

# %%
df['Country'].value_counts()
# Out:
# Country
# France          31
# Argentina       30
# Colombia        30
# Chile           29
# South Africa    29
# Germany         28
# Italy           28
# Mexico          28
# Indonesia       27
# China           26
# India           26
# USA             25
# Canada          24
# Turkey          24
# Vietnam         24
# Brazil          23
# Ethiopia        23
# Kenya           23
# Thailand        22
# Peru            20
# Name: count, dtype: int64

# %% [markdown]
# ****10) Find the minimum, maximum, and average of total production.****

# %%
df.head(5)
# Out:
#    Unnamed: 0  Year    Country  Domestic Consumption  Exports  Import Price  \
# 0           0  2015  Argentina               13051.0  14887.0           2.6
# 1           1  2015  Argentina               13131.0  15055.0           2.6
# 2           2  2015  Argentina               13305.0  15075.0           2.7
# 3           3  2015     Brazil               21070.0  36806.0           1.9
# 4           4  2015     Canada               18063.0  21734.0           3.9
#
#    Export Price  Total Production
# 0           2.7           26614.0
# 1           3.0           27019.0
# 2           NaN           27232.0
# 3           1.9           54721.0
# 4           4.0           38987.0

# %%
df['Total Production'].min()
# Out:
# np.float64(0.0)

# %%
df['Total Production'].max()
# Out:
# np.float64(264565.0)

# %%
df['Total Production'].mean()
# Out:
# np.float64(46466.72672064777)

# %% [markdown]
# ****11) Which country has the highest total production in a single record?****

# %%
df[df['Total Production'] == df['Total Production'].max()]['Country']
# Out:
# 480    China
# Name: Country, dtype: str

# %% [markdown]
# ****12) Are there any rows where total production is missing or zero?****

# %%
print(df[df['Total Production'].isnull()])
df['Total Production'].isnull().sum()
# Out:
#      Unnamed: 0  Year       Country  Domestic Consumption   Exports  \
# 14           14  2015         China              119776.0   85031.0
# 31           31  2015       Germany                8197.0   10984.0
# 44           44  2015         Kenya                7944.0   11797.0
# 55           55  2015  South Africa               10890.0   12848.0
# 73           73  2016     Argentina               13200.0   15180.0
# 117         117  2016          Peru                6554.0    8714.0
# 161         161  2017         India               48027.0   26165.0
# 162         162  2017     Indonesia               29146.0   33307.0
# 183         183  2017        Turkey               19623.0   22288.0
# 207         207  2018        France               31203.0   33332.0
# 228         228  2018           USA               26679.0       0.0
# 234         234  2019     Argentina               14151.0   16489.0
# 237         237  2019        Brazil               23077.0   40946.0
# ...

# %%
df[df['Total Production'] == 0]
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 27           27  2015  Germany                8514.0  11030.0           3.2
# 28           28  2015  Germany                8514.0  11030.0           3.2
# 29           29  2015  Germany                8887.0  11273.0           3.4
# 30           30  2015  Germany                8396.0  10988.0           3.0
# 32           32  2015  Germany                8121.0  11043.0           3.1
# 63           63  2015      USA               24902.0      NaN           4.6
# 64           64  2015      USA               25244.0      0.0           4.4
# 65           65  2015      USA                   NaN      0.0           4.4
# 66           66  2015      USA               24831.0      0.0           4.2
# 94           94  2016  Germany                8792.0  11048.0           3.3
# 95           95  2016  Germany                8670.0  10868.0           3.2
# ...

# %% [markdown]
# ****13) What is the average import price across all records?****

# %%
df['Import Price'].mean()
# Out:
# np.float64(3.1564777327935225)

# %% [markdown]
# ****14) What is the total coffee production for each year?****

# %%
for y in df['Year'].unique():
    print(y, df[df['Year'] == y]['Total Production'].sum())
# Out:
# 2015 2551154.0
# 2016 2163533.0
# 2017 2438153.0
# 2018 1793354.0
# 2019 2593378.0
# 2020 2756933.0
# 2021 2867085.0
# 2022 2681517.0
# 2023 3109456.0

# %%
yearly_production = df.groupby('Year')['Total Production'].sum()

print(yearly_production)
# Out:
# Year
# 2015    2551154.0
# 2016    2163533.0
# 2017    2438153.0
# 2018    1793354.0
# 2019    2593378.0
# 2020    2756933.0
# 2021    2867085.0
# 2022    2681517.0
# 2023    3109456.0
# Name: Total Production, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(yearly_production.index, yearly_production.values)
plt.xlabel("Year")
plt.ylabel("Total Production")
plt.title("Year-wise Coffee Production")
plt.show()

# %% [markdown]
# ****15) Which are the top 5 countries based on total production?****

# %%
top5 = df.groupby('Country')['Total Production'].sum().sort_values(ascending=False).head(5)

top5
# Out:
# Country
# China        5682192.0
# India        1902283.0
# Mexico       1838210.0
# France       1837554.0
# Indonesia    1582361.0
# Name: Total Production, dtype: float64

# %%
plt.barh(top5.index, top5.values, color = ['red', 'blue', 'green', 'yellow', 'orange'])
plt.xlabel("Total Production")
plt.ylabel("Country")
plt.title("Top 5 Coffee Producing Countries")
plt.show()

# %% [markdown]
# ****16) Which country has the highest average export price?****

# %%
avg_price = df.groupby('Country')['Export Price'].mean()
avg_price.sort_values(ascending=False).head(1)
# Out:
# Country
# Canada    4.338095
# Name: Export Price, dtype: float64

# %% [markdown]
# ****17) Does domestic consumption exceed total production for any country?****

# %%
country_totals = df.groupby('Country')[['Domestic Consumption', 'Total Production']].sum()
country_totals[country_totals['Domestic Consumption'] > country_totals['Total Production']]
# Out:
#          Domestic Consumption  Total Production
# Country
# Germany              236301.0               0.0
# USA                  632149.0               0.0

# %% [markdown]
# ****18) Which country shows the highest growth in total production over the years?****

# %%
df1 = df.sort_values('Year')
grouped = df1.groupby(['Country', 'Year'])['Total Production'].sum()
start = grouped.groupby('Country').first()
end = grouped.groupby('Country').last()
growth = end - start

highest_growth = growth[growth == growth.max()]
print(highest_growth)
# Out:
# Country
# China    720940.0
# Name: Total Production, dtype: float64

# %%
plt.barh(growth.index, growth.values, color = ['red', 'green', 'blue'])
plt.xlabel("Production Growth")
plt.ylabel("Country")
plt.title("Production Growth by Country")
plt.show()

# %% [markdown]
# ****19) Is there any relationship between export price and total production?****

# %%
df['Export Price'].corr(df['Total Production'])
# Out:
# np.float64(0.34420346614210934)

# %%
plt.scatter(df['Total Production'], df['Export Price'])
plt.xlabel("Total Production")
plt.ylabel("Export Price")
plt.title("Export Price vs Total Production")
plt.show()

# %% [markdown]
# ****20) Write 4–5 lines summarizing key insights from the EDA.****

# %% [markdown]
# 1. Coffee production is concentrated among a few major producers, especially China.
# 2. Some developed countries (Germany, USA) consume more than they produce.
# 3. Export pricing does not strongly depend on production volume.
# 4. Production has generally grown over the 2015–2023 period for key producers.
